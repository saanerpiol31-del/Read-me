# %% [markdown]
# <a href="https://colab.research.google.com/github/saanerpiol31-del/Read-me/blob/main/Q1_NARRA_FA1_NERPIOL.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import math
int(input("x1"))
int(input("x2"))
int(input("y1"))
int(input("y2"))

d = pow((x2 - x1), 2) + pow((y2 - y1 ), 2)
print(math.sqrt(d))


#When using a library it is more practical because it is easier and automatic. You can also see where you got it wrong to help you.
# Out:
# x12
# x23
